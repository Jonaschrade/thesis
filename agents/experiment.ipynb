# %%
import random, json

# %%
with open("agents/personas.json", "r") as f:
    data = json.load(f)

# %%
personas=random.sample(data,2)

# %%
personas
# Out:
# ["a museum curator specializing in abstract expressionism who offers insights on the historical significance and cultural context of Bloch's paintings",
#  'a political scientist analyzing the impact of ideology on military strategies']
